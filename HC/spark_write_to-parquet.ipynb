# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import split, col, element_at, slice, size, regexp_extract, transform, when, explode, \
monotonically_increasing_id, map_from_arrays, lit, udf,collect_list, row_number, ceil, map_keys, expr, from_json
from pyspark.sql.types import ShortType, ArrayType, LongType, StringType
from pyspark.sql import types as T

from IPython.display import display
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error
from scipy.stats import zscore
import gzip
import os
import csv
from alive_progress import alive_bar
from collections import defaultdict
import pandas as pd
from os import listdir
from os.path import isfile, join
import sys

directory = 'C:/Users/bincl/BA-Thesis/Dataset/2gram/default/2_20000_nopos_aa.gz'


        # checking if it is a file
spark = SparkSession.builder.appName('3gramSQL').getOrCreate()

raw_input_df = spark \
        .read.csv(directory, sep='\n',quote="").withColumnRenamed('_c0', 'Input')

split_df = raw_input_df \
                        .select(split('Input', '\t').alias('SplitInput')) \
                        .select(element_at('SplitInput', 1).alias('Tokens'),
                                slice('SplitInput', 2,
        size('SplitInput')).alias('Data')) \
                        .select('Tokens', 'Data') \

df_2gram = split_df.select('Tokens', transform('Data', lambda d:
        split(d, ',')).alias('Data')) \
                        .select('Tokens', transform('Data', lambda x:
        x[0]).alias('Year'),
                                transform('Data', lambda x:
        x[1]).cast(ArrayType(LongType())).alias('Occurrences')) \
                        .select('Tokens', map_from_arrays('Year',
        'Occurrences').alias('Data')) \
                        .select(['Tokens', 'Data'])  
df_2gram.printSchema()
# Out:
# c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\__init__.py:169: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# root
#  |-- Tokens: string (nullable = true)
#  |-- Data: map (nullable = true)
#  |    |-- key: string
#  |    |-- value: long (valueContainsNull = true)

# %%
baisic = spark.read.parquet("C:/Users/bincl/BA-Thesis/Dataset/2gram/parquet/aa.gz.parquet", header=True, inferSchema=True)

baisic.printSchema()

baisic.head(3)
# Out:
# root
#  |-- derartige Beachtung: string (nullable = true)
#  |-- 1850,2,1: string (nullable = true)
#  |-- 1855,2,2: string (nullable = true)
#  |-- 1860,1,1: string (nullable = true)
#  |-- 1865,6,6: string (nullable = true)
#  |-- 1868,1,1: string (nullable = true)
#  |-- 1871,1,1: string (nullable = true)
#  |-- 1875,3,2: string (nullable = true)
#  |-- 1878,1,1: string (nullable = true)
#  |-- 1880,1,1: string (nullable = true)
#  |-- 1882,1,1: string (nullable = true)
#  |-- 1884,1,1: string (nullable = true)
#  |-- 1885,2,2: string (nullable = true)
#  |-- 1886,2,2: string (nullable = true)
#  |-- 1891,4,4: string (nullable = true)
#  |-- 1893,1,1: string (nullable = true)
#  |-- 1895,2,2: string (nullable = true)
#  |-- 1896,4,4: string (nullable = true)
#  |-- 1897,1,1: string (nullable = true)
#  |-- 1899,4,4: string (nullable = true)
#  |-- 1900,4,4: string (nullable = true)
#  |-- 1901,2,2: string (nullable = true)
#  |-- 1902,9,9: string (nullable = true)
#  |-- 1903,6,6: string (nullable = true)
#  |-- 1904,2,2: string (nullable = true)
#  |-- 1905,8,8: string (nullable = true)
#  |-- 1906,6,6: string (nullable = true)
#  |-- 1907,10,10: string (nullable = true)
#  |-- 1908,6,6: string (nullable = true)
#  |-- 1910,1,1: string (nullable = true)
#  |-- 1912,4,4: string (nullable = true)
#  |-- 1913,3,3: string (nullable = true)
#  |-- 1915,6,6: string (nullable = true)
#  |-- 1916,5,5: string (nullable = true)
#  |-- 1917,1,1: string (nullable = true)
#  |-- 1919,3,3: string (nullable = true)
#  |-- 1920,7,7: string (nullable = true)
#  |-- 1921,4,4: string (nullable = true)
#  |-- 1922,7,6: string (nullable = true)
#  |-- 1924,1,1: string (nullable = true)
#  |-- 1925,1,1: string (nullable = true)
#  |-- 1926,1,1: string (nullable = true)
#  |-- 1927,4,4: string (nullable = true)
#  |-- 1928,1,1: string (nullable = true)
#  |-- 1929,1,1: string (nullable = true)
#  |-- 1930,2,2: string (nullable = true)
#  |-- 1931,3,3: string (nullable = true)
#  |-- 1933,1,1: string (nullable = true)
#  |-- 1935,4,4: string (nullable = true)
#  |-- 1937,3,3: string (nullable = true)
#  |-- 1938,1,1: string (nullable = true)
#  |-- 1939,1,1: string (nullable = true)
#  |-- 1943,1,1: string (nullable = true)
#  |-- 1948,3,3: string (nullable = true)
#  |-- 1949,4,4: string (nullable = true)
#  |-- 1950,1,1: string (nullable = true)
#  |-- 1951,1,1: string (nullable = true)
#  |-- 1952,2,2: string (nullable = true)
#  |-- 1953,1,1: string (nullable = true)
#  |-- 1955,4,4: string (nullable = true)
#  |-- 1956,2,2: string (nullable = true)
#  |-- 1958,2,2: string (nullable = true)
#  |-- 1959,3,3: string (nullable = true)
#  |-- 1960,2,2: string (nullable = true)
#  |-- 1961,1,1: string (nullable = true)
#  |-- 1962,6,6: string (nullable = true)
#  |-- 1963,6,6: string (nullable = true)
#  |-- 1964,8,8: string (nullable = true)
#  |-- 1965,1,1: string (nullable = true)
#  |-- 1966,3,3: string (nullable = true)
#  |-- 1967,4,4: string (nullable = true)
#  |-- 1968,2,2: string (nullable = true)
#  |-- 1969,2,2: string (nullable = true)
#  |-- 1970,2,2: string (nullable = true)
#  |-- 1971,8,8: string (nullable = true)
#  |-- 1972,2,2: string (nullable = true)
#  |-- 1973,5,5: string (nullable = true)
#  |-- 1974,13,13: string (nullable = true)
#  |-- 1975,3,3: string (nullable = true)
#  |-- 1976,1,1: string (nullable = true)
#  |-- 1977,3,3: string (nullable = true)
#  |-- 1978,3,3: string (nullable = true)
#  |-- 1979,4,4: string (nullable = true)
#  |-- 1980,4,4: string (nullable = true)
#  |-- 1981,3,3: string (nullable = true)
#  |-- 1982,4,4: string (nullable = true)
#  |-- 1983,4,4: string (nullable = true)
#  |-- 1984,4,4: string (nullable = true)
#  |-- 1985,3,3: string (nullable = true)
#  |-- 1986,6,6: string (nullable = true)
#  |-- 1987,1,1: string (nullable = true)
#  |-- 1988,4,4: string (nullable = true)
#  |-- 1991,5,5: string (nullable = true)
#  |-- 1992,3,3: string (nullable = true)
#  |-- 1993,3,3: string (nullable = true)
#  |-- 1994,3,3: string (nullable = true)
#  |-- 1995,7,7: string (nullable = true)
#  |-- 1996,3,3: string (nullable = true)
#  |-- 1997,3,3: string (nullable = true)
#  |-- 1998,6,6: string (nullable = true)
#  |-- 1999,2,2: string (nullable = true)
#  |-- 2000,5,5: string (nullable = true)
#  |-- 2001,4,4: string (nullable = true)
#  |-- 2002,3,3: string (nullable = true)
#  |-- 2003,3,3: string (nullable = true)
#  |-- 2004,12,12: string (nullable = true)
#  |-- 2005,6,6: string (nullable = true)
#  |-- 2006,4,4: string (nullable = true)
#  |-- 2007,5,5: string (nullable = true)
#  |-- 2008,9,9: string (nullable = true)
#  |-- 2009,1,1: string (nullable = true)
#  |-- 2010,5,5: string (nullable = true)
#  |-- 2011,4,4: string (nullable = true)
#  |-- 2012,3,3: string (nullable = true)
#  |-- 2013,16,16: string (nullable = true)
#  |-- 2014,3,3: string (nullable = true)
#  |-- 2015,7,7: string (nullable = true)
#  |-- 2016,3,3: string (nullable = true)
#  |-- 2017,16,13: string (nullable = true)
#  |-- 2018,7,7: string (nullable = true)
#  |-- 2019,1,1: string (nullable = true)
#  |-- __index_level_0__: string (nullable = true)
#  |-- __index_level_1__: string (nullable = true)
#  |-- __index_level_2__: string (nullable = true)
#  |-- __index_level_3__: string (nullable = true)
#  |-- __index_level_4__: string (nullable = true)
#  |-- __index_level_5__: string (nullable = true)
#  |-- __index_level_6__: string (nullable = true)
#  |-- __index_level_7__: string (nullable = true)
#  |-- __index_level_8__: string (nullable = true)
#  |-- __index_level_9__: string (nullable = true)
#  |-- __index_level_10__: string (nullable = true)
#  |-- __index_level_11__: string (nullable = true)
#  |-- __index_level_12__: string (nullable = true)
#  |-- __index_level_13__: string (nullable = true)
#  |-- __index_level_14__: string (nullable = true)
#  |-- __index_level_15__: string (nullable = true)
#  |-- __index_level_16__: string (nullable = true)
#  |-- __index_level_17__: string (nullable = true)
#  |-- __index_level_18__: string (nullable = true)
#  |-- __index_level_19__: string (nullable = true)
#  |-- __index_level_20__: string (nullable = true)
#  |-- __index_level_21__: string (nullable = true)
#  |-- __index_level_22__: string (nullable = true)
#  |-- __index_level_23__: string (nullable = true)
#  |-- __index_level_24__: string (nullable = true)
#  |-- __index_level_25__: string (nullable = true)
#  |-- __index_level_26__: string (nullable = true)
#  |-- __index_level_27__: string (nullable = true)
#  |-- __index_level_28__: string (nullable = true)
#  |-- __index_level_29__: string (nullable = true)
#  |-- __index_level_30__: string (nullable = true)
#  |-- __index_level_31__: string (nullable = true)
#  |-- __index_level_32__: string (nullable = true)
#  |-- __index_level_33__: string (nullable = true)
#  |-- __index_level_34__: string (nullable = true)
#  |-- __index_level_35__: string (nullable = true)
#  |-- __index_level_36__: string (nullable = true)
#  |-- __index_level_37__: string (nullable = true)
#  |-- __index_level_38__: string (nullable = true)
#  |-- __index_level_39__: string (nullable = true)
#  |-- __index_level_40__: string (nullable = true)
#  |-- __index_level_41__: string (nullable = true)
#  |-- __index_level_42__: string (nullable = true)
#  |-- __index_level_43__: string (nullable = true)
#  |-- __index_level_44__: string (nullable = true)
#  |-- __index_level_45__: string (nullable = true)
#  |-- __index_level_46__: string (nullable = true)
#  |-- __index_level_47__: string (nullable = true)
#  |-- __index_level_48__: string (nullable = true)
#  |-- __index_level_49__: string (nullable = true)
#  |-- __index_level_50__: string (nullable = true)
#  |-- __index_level_51__: string (nullable = true)
#  |-- __index_level_52__: string (nullable = true)
#  |-- __index_level_53__: string (nullable = true)
#  |-- __index_level_54__: string (nullable = true)
#  |-- __index_level_55__: string (nullable = true)
#  |-- __index_level_56__: string (nullable = true)
#  |-- __index_level_57__: string (nullable = true)
#  |-- __index_level_58__: string (nullable = true)
#  |-- __index_level_59__: string (nullable = true)
#  |-- __index_level_60__: string (nullable = true)
#  |-- __index_level_61__: string (nullable = true)
#  |-- __index_level_62__: string (nullable = true)
#  |-- __index_level_63__: string (nullable = true)
#  |-- __index_level_64__: string (nullable = true)
#  |-- __index_level_65__: string (nullable = true)
#  |-- __index_level_66__: string (nullable = true)
#  |-- __index_level_67__: string (nullable = true)
#  |-- __index_level_68__: string (nullable = true)
#  |-- __index_level_69__: string (nullable = true)
#  |-- __index_level_70__: string (nullable = true)
#  |-- __index_level_71__: string (nullable = true)
#  |-- __index_level_72__: string (nullable = true)
#  |-- __index_level_73__: string (nullable = true)
#  |-- __index_level_74__: string (nullable = true)
#  |-- __index_level_75__: string (nullable = true)
#  |-- __index_level_76__: string (nullable = true)
#  |-- __index_level_77__: string (nullable = true)
#  |-- __index_level_78__: string (nullable = true)
#  |-- __index_level_79__: string (nullable = true)
#  |-- __index_level_80__: string (nullable = true)
#  |-- __index_level_81__: string (nullable = true)
#  |-- __index_level_82__: string (nullable = true)
#  |-- __index_level_83__: string (nullable = true)
#  |-- __index_level_84__: string (nullable = true)
#  |-- __index_level_85__: string (nullable = true)
#  |-- __index_level_86__: string (nullable = true)
#  |-- __index_level_87__: string (nullable = true)
#  |-- __index_level_88__: string (nullable = true)
#  |-- __index_level_89__: string (nullable = true)
#  |-- __index_level_90__: string (nullable = true)
#  |-- __index_level_91__: string (nullable = true)
#  |-- __index_level_92__: string (nullable = true)
#  |-- __index_level_93__: string (nullable = true)
#  |-- __index_level_94__: string (nullable = true)
#  |-- __index_level_95__: string (nullable = true)
#  |-- __index_level_96__: string (nullable = true)
#  |-- __index_level_97__: string (nullable = true)
#  |-- __index_level_98__: string (nullable = true)
#  |-- __index_level_99__: string (nullable = true)
#  |-- __index_level_100__: string (nullable = true)
#  |-- __index_level_101__: string (nullable = true)
#  |-- __index_level_102__: string (nullable = true)
#  |-- __index_level_103__: string (nullable = true)
#  |-- __index_level_104__: string (nullable = true)
#  |-- __index_level_105__: string (nullable = true)
#  |-- __index_level_106__: string (nullable = true)
#  |-- __index_level_107__: string (nullable = true)
#  |-- __index_level_108__: string (nullable = true)
#  |-- __index_level_109__: string (nullable = true)
#  |-- __index_level_110__: string (nullable = true)
#  |-- __index_level_111__: string (nullable = true)
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "C:\Users\bincl\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 3433, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\bincl\AppData\Local\Temp\ipykernel_2016\1021516161.py", line 5, in <module>
#     baisic.head(3)
#   File "c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\sql\dataframe.py", line 2969, in head
#     return self.take(n)
#            ^^^^^^^^^^^^
#   File "c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\sql\dataframe.py", line 1401, in take
#     return self.limit(num).collect()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\sql\dataframe.py", line 1257, in collect
#     sock_info = self._jdf.collectToPython()
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\java_gateway.py", line 1322, in __call__
#     return_value = get_return_value(
#                    ^^^^^^^^^^^^^^^^^
#   File "c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\errors\exceptions\captured.py", line 179, in deco
#     return f(*a, **kw)
#            ^^^^^^^^^^^
#   File "c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\protocol.py", line 326, in get_return_value
#     raise Py4JJavaError(
# py4j.protocol.Py4JJavaError: <exception str() failed>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Eine vorhandene Verbindung wurde vom Remotehost geschlossen
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Eine vorhandene Verbindung wurde vom Remotehost geschlossen
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[2], line 5
#       3 baisic.printSchema()
# ----> 5 baisic.head(3)
#
# File c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\sql\dataframe.py:2969, in DataFrame.head(self, n)
#    2968     return rs[0] if rs else None
# -> 2969 return self.take(n)
#
# File c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\sql\dataframe.py:1401, in DataFrame.take(self, num)
#    1373 """Returns the first ``num`` rows as a :class:`list` of :class:`Row`.
#    1374
#    1375 .. versionadded:: 1.3.0
#    (...)
#    1399 [Row(age=14, name='Tom'), Row(age=23, name='Alice')]
#    1400 """
# -> 1401 return self.limit(num).collect()
#
# File c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\sql\dataframe.py:1257, in DataFrame.collect(self)
#    1256 with SCCallSiteSync(self._sc):
# -> 1257     sock_info = self._jdf.collectToPython()
#    1258 return list(_load_from_socket(sock_info, BatchedSerializer(CPickleSerializer())))
#
# File c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#
# File c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\errors\exceptions\captured.py:179, in capture_sql_exception.<locals>.deco(*a, **kw)
#     178 try:
# --> 179     return f(*a, **kw)
#     180 except Py4JJavaError as e:
#
# File c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\protocol.py:326, in get_return_value(answer, gateway_client, target_id, name)
#     325 if answer[1] == REFERENCE_TYPE:
# --> 326     raise Py4JJavaError(
#     327         "An error occurred while calling {0}{1}{2}.\n".
#     328         format(target_id, ".", name), value)
#     329 else:
#
# <class 'str'>: (<class 'ConnectionRefusedError'>, ConnectionRefusedError(10061, 'Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte', None, 10061, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:2063, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2060     traceback.print_exc()
#    2061     return None
# -> 2063 self._showtraceback(etype, value, stb)
#    2064 if self.call_pdb:
#    2065     # drop into debugger
#    2066     self.debugger(force=True)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\zmqshell.py:541, in ZMQInteractiveShell._showtraceback(self, etype, evalue, stb)
#     535 sys.stdout.flush()
#     536 sys.stderr.flush()
#     538 exc_content = {
#     539     "traceback": stb,
#     540     "ename": str(etype.__name__),
# --> 541     "evalue": str(evalue),
#     542 }
#     544 dh = self.displayhook
#     545 # Send exception info over pub socket for other clients than the caller
#     546 # to pick up
#
# File c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\protocol.py:471, in Py4JJavaError.__str__(self)
#     469 def __str__(self):
#     470     gateway_client = self.java_exception._gateway_client
# --> 471     answer = gateway_client.send_command(self.exception_cmd)
#     472     return_value = get_return_value(answer, gateway_client, None, None)
#     473     # Note: technically this should return a bytestring 'str' rather than
#     474     # unicodes in Python 2; however, it can return unicodes for now.
#     475     # See https://github.com/bartdag/py4j/issues/306 for more details.
#
# File c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\java_gateway.py:1036, in GatewayClient.send_command(self, command, retry, binary)
#    1015 def send_command(self, command, retry=True, binary=False):
#    1016     """Sends a command to the JVM. This method is not intended to be
#    1017        called directly by Py4J users. It is usually called by
#    1018        :class:`JavaMember` instances.
#    (...)
#    1034      if `binary` is `True`.
#    1035     """
# -> 1036     connection = self._get_connection()
#    1037     try:
#    1038         response = connection.send_command(command)
#
# File c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\clientserver.py:284, in JavaClient._get_connection(self)
#     281     pass
#     283 if connection is None or connection.socket is None:
# --> 284     connection = self._create_new_connection()
#     285 return connection
#
# File c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\clientserver.py:291, in JavaClient._create_new_connection(self)
#     287 def _create_new_connection(self):
#     288     connection = ClientServerConnection(
#     289         self.java_parameters, self.python_parameters,
#     290         self.gateway_property, self)
# --> 291     connection.connect_to_java_server()
#     292     self.set_thread_connection(connection)
#     293     return connection
#
# File c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\py4j\clientserver.py:438, in ClientServerConnection.connect_to_java_server(self)
#     435 if self.ssl_context:
#     436     self.socket = self.ssl_context.wrap_socket(
#     437         self.socket, server_hostname=self.java_address)
# --> 438 self.socket.connect((self.java_address, self.java_port))
#     439 self.stream = self.socket.makefile("rb")
#     440 self.is_connected = True
#
# ConnectionRefusedError: [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte

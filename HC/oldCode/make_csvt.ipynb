# %%
from IPython.display import display
import pandas as pd
import os
import csv

# %%
def read_in(string):
    df = pd.read_csv(string, compression='gzip', header=0, sep='\t', quotechar='"', on_bad_lines='skip', quoting=csv.QUOTE_NONE)
    first, *middle, last = string.split("_")
    df.to_parquet( last +'.parquet', index= False)

# %%
directory = 'C:/Users/bincl/BA-Thesis/Dataset/2gram/default'

for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    # checking if it is a file
    if os.path.isfile(f):
        read_in(f)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 7
#       5 # checking if it is a file
#       6 if os.path.isfile(f):
# ----> 7     read_in(f)
#
# Cell In[11], line 4, in read_in(string)
#       2 df = pd.read_csv(string, compression='gzip', header=0, sep='\t', quotechar='"', on_bad_lines='skip', quoting=csv.QUOTE_NONE)
#       3 first, *middle, last = string.split("_")
# ----> 4 df.to_parquet( last +'.parquet', index= False)
#
# File c:\Users\bincl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %%
df = pd.read_parquet('C:/Users/bincl/BA-Thesis/Dataset/2gram/parquet/aa.gz.parquet')
print(df)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...
